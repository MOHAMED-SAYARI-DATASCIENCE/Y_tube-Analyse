# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = r"C:\Users\MSI\Desktop\project For Me\Nouveau dossier\projet 2\Global-YouTube-Statistics.xlsx"
data = pd.read_excel(url)

print(data)
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  228000000000
# 1       2              YouTube Movies    170000000             0
# 2       3                     MrBeast    166000000   28368841870
# 3       4  Cocomelon - Nursery Rhymes    162000000  164000000000
# 4       5                   SET India    159000000  148000000000
# ..    ...                         ...          ...           ...
# 990   991                       False     12300000    9029609749
# 991   992    Free Fire India Official     12300000    1674409945
# 992   993                       Panda     12300000    2214684303
# 993   994                 RobTopGames     12300000     374123483
# 994   995                Make Joke Of     12300000    2129773714
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# 1    Film & Animation               youtubemovies        1   United States
# 2       Entertainment                     MrBeast      741   United States
# 3           Education  Cocomelon - Nursery Rhymes      966   United States
# 4               Shows                   SET India   116536           India
# ..                ...                         ...      ...             ...
# 990            Sports                       False     1200          Brazil
# 991    People & Blogs    Free Fire India Official     1500           India
# 992               NaN                 HybridPanda     2452  United Kingdom
# 993            Gaming                 RobTopGames       39          Sweden
# 994            Comedy                Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0             IN          Music  ...                    2000000.00
# 1             US          Games  ...                           NaN
# 2             US  Entertainment  ...                    8000000.00
# 3             US      Education  ...                    1000000.00
# 4             IN  Entertainment  ...                    1000000.00
# ..           ...            ...  ...                           ...
# 990           BR  Entertainment  ...                     700000.00
# 991           IN          Games  ...                     300000.00
# 992           GB          Games  ...                       1000.00
# 993           SE          Games  ...                     100000.00
# 994           IN         Comedy  ...                     100000.00
#
#      created_year  created_month  created_date  \
# 0         2006.00            Mar         13.00
# 1         2006.00            Mar          5.00
# 2         2012.00            Feb         20.00
# 3         2006.00            Sep          1.00
# 4         2006.00            Sep         20.00
# ..            ...            ...           ...
# 990       2017.00            Feb         12.00
# 991       2018.00            Sep         14.00
# 992       2006.00            Sep         11.00
# 993       2012.00            May          9.00
# 994       2017.00            Aug          1.00
#
#      Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                      28.10 1366417754.00               5.36
# 1                                      88.20  328239523.00              14.70
# 2                                      88.20  328239523.00              14.70
# 3                                      88.20  328239523.00              14.70
# 4                                      28.10 1366417754.00               5.36
# ..                                       ...           ...                ...
# 990                                    51.30  212559417.00              12.08
# 991                                    28.10 1366417754.00               5.36
# 992                                    60.00   66834405.00               3.85
# 993                                    67.00   10285453.00               6.48
# 994                                    28.10 1366417754.00               5.36
#
#      Urban_population  Latitude  Longitude
# 0        471031528.00     20.59      78.96
# 1        270663028.00     37.09     -95.71
# 2        270663028.00     37.09     -95.71
# 3        270663028.00     37.09     -95.71
# 4        471031528.00     20.59      78.96
# ..                ...       ...        ...
# 990      183241641.00    -14.24     -51.93
# 991      471031528.00     20.59      78.96
# 992       55908316.00     55.38      -3.44
# 993        9021165.00     60.13      18.64
# 994      471031528.00     20.59      78.96
#
# [995 rows x 28 columns]

# %%
data.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  228000000000
# 1     2              YouTube Movies    170000000             0
# 2     3                     MrBeast    166000000   28368841870
# 3     4  Cocomelon - Nursery Rhymes    162000000  164000000000
# 4     5                   SET India    159000000  148000000000
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                    2000000.00
# 1           US          Games  ...                           NaN
# 2           US  Entertainment  ...                    8000000.00
# 3           US      Education  ...                    1000000.00
# 4           IN  Entertainment  ...                    1000000.00
#
#    created_year  created_month  created_date  \
# 0       2006.00            Mar         13.00
# 1       2006.00            Mar          5.00
# 2       2012.00            Feb         20.00
# 3       2006.00            Sep          1.00
# 4       2006.00            Sep         20.00
#
#    Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                    28.10 1366417754.00               5.36
# 1                                    88.20  328239523.00              14.70
# 2                                    88.20  328239523.00              14.70
# 3                                    88.20  328239523.00              14.70
# 4                                    28.10 1366417754.00               5.36
#
#    Urban_population  Latitude  Longitude
# 0      471031528.00     20.59      78.96
# 1      270663028.00     37.09     -95.71
# 2      270663028.00     37.09     -95.71
# 3      270663028.00     37.09     -95.71
# 4      471031528.00     20.59      78.96
#
# [5 rows x 28 columns]

# %%
df.tail()
# Out:
#      rank                  Youtuber  subscribers  video views        category  \
# 990   991                     False     12300000   9029609749          Sports
# 991   992  Free Fire India Official     12300000   1674409945  People & Blogs
# 992   993                     Panda     12300000   2214684303             NaN
# 993   994               RobTopGames     12300000    374123483          Gaming
# 994   995              Make Joke Of     12300000   2129773714          Comedy
#
#                         Title  uploads         Country Abbreviation  \
# 990                     False     1200          Brazil           BR
# 991  Free Fire India Official     1500           India           IN
# 992               HybridPanda     2452  United Kingdom           GB
# 993               RobTopGames       39          Sweden           SE
# 994              Make Joke Of       62           India           IN
#
#       channel_type  ...  subscribers_for_last_30_days  created_year  \
# 990  Entertainment  ...                     700000.00       2017.00
# 991          Games  ...                     300000.00       2018.00
# 992          Games  ...                       1000.00       2006.00
# 993          Games  ...                     100000.00       2012.00
# 994         Comedy  ...                     100000.00       2017.00
#
#      created_month  created_date  Gross tertiary education enrollment (%)  \
# 990            Feb         12.00                                    51.30
# 991            Sep         14.00                                    28.10
# 992            Sep         11.00                                    60.00
# 993            May          9.00                                    67.00
# 994            Aug          1.00                                    28.10
#
#        Population  Unemployment rate  Urban_population  Latitude  Longitude
# 990  212559417.00              12.08      183241641.00    -14.24     -51.93
# 991 1366417754.00               5.36      471031528.00     20.59      78.96
# 992   66834405.00               3.85       55908316.00     55.38      -3.44
# 993   10285453.00               6.48        9021165.00     60.13      18.64
# 994 1366417754.00               5.36      471031528.00     20.59      78.96
#
# [5 rows x 28 columns]

# %%
data.shape
# Out:
# (995, 28)

# %%
data.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
data.dtypes
# Out:
# rank                                         int64
# Youtuber                                    object
# subscribers                                  int64
# video views                                  int64
# category                                    object
# Title                                       object
# uploads                                      int64
# Country                                     object
# Abbreviation                                object
# channel_type                                object
# video_views_rank                           float64
# country_rank                               float64
# channel_type_rank                          float64
# video_views_for_the_last_30_days           float64
# lowest_monthly_earnings                    float64
# highest_monthly_earnings                   float64
# lowest_yearly_earnings                     float64
# highest_yearly_earnings                    float64
# subscribers_for_last_30_days               float64
# created_year                               float64
# created_month                               object
# created_date                               float64
# Gross tertiary education enrollment (%)    float64
# Population                                 float64
# Unemployment rate                          float64
# Urban_population                           float64
# Latitude                                   float64
# Longitude                                  float64
# dtype: object

# %%
data["Youtuber"].unique()
# Out:
# array(['T-Series', 'YouTube Movies', 'MrBeast',
#        'Cocomelon - Nursery Rhymes', 'SET India', 'Music', False,
#        'PewDiePie', 'Like Nastya', 'Vlad and Niki', 'Zee Music Company',
#        'WWE', 'Gaming', 'BLACKPINK', 'Goldmines', 'Sony SAB',
#        '5-Minute Crafts', 'BANGTANTV', 'Sports', 'Justin Bieber',
#        'HYBE LABELS', 'Zee TV',
#        "Pinkfong Baby Shark - Kids' Songs & Stories", 'Canal KondZilla',
#        'ChuChu TV Nursery Rhymes & Kids Songs', 'Shemaroo Filmi Gaane',
#        'Colors TV', 'T-Series Bhakti Sagar', 'Dude Perfect', 'Movieclips',
#        'Tips Official', 'El Reino Infantil', 'Wave Music', 'Aaj Tak',
#        'Sony Music India', 'EminemMusic', 'Marshmello', 'YRF',
#        "LooLoo Kids - Nursery Rhymes and Children's Songs", 'Ed Sheeran',
#        'Infobells - Hindi', 'Taylor Swift', 'Ariana Grande',
#        'BillionSurpriseToys  - Nursery Rhymes & Cartoons', 'JuegaGerman',
#        'Billie Eilish', 'Get Movies', 'Shemaroo', 'Badabun',
#        'SonyMusicIndiaVEVO', 'A4', 'Bad Bunny', 'Fernanfloo', 'Voot Kids',
#        'Felipe Neto', 'Voc���', 'HAR PAL GEO', 'BRIGHT SIDE',
#        'Katy Perry', 'whinderssonnunes', 'ABS-CBN Entertainment',
#        'Alan Walker', 'HolaSoyGerman.', 'Shakira', 'ARY Digital HD',
#        'Speed Records', 'Masha and The Bear', 'Like Nastya Show',
#        'Rihanna', 'Ishtar Music', 'Kimberly Loaiza',
#        'Little Baby Bum - Nursery Rhymes & Kids Songs',
#        'Luisito Comunica', 'elrubiusOMG', 'Toys and Colors', 'shfa2 - ��',
#        'LUCCAS NETO - LUCCAS TOON', 'CarryMinati', 'XXXTENTACION',
#        'Super Simple Songs - Kids Songs', 'Mikecrack',
#        'WorkpointOfficial', 'GR6 EXPLODE', 'TEDx Talks', 'shfa',
#        'Goldmines Gaane Sune Ansune', 'One Direction', 'TheEllenShow',
#        'Sony PAL', 'Daddy Yankee', 'Like Nastya ESP', 'Jkk Entertainment',
#        'ABP NEWS', 'Maria Clara & JP', 'Bruno Mars', 'Maroon 5',
#        'Ultra Bollywood', 'PowerKids TV', 'YouTube', 'News', 'Ozuna',
#        'MrBeast Gaming', 'La Granja de Zen�', 'Saregama Music', 'IndiaTV',
#        'T-Series Bollywood Classics', 'Total Gaming', 'Markiplier',
#        "Ryan's World", "Genevieve's Playhouse - Learning Videos for Kids",
#        'T-Series Apna Punjab', 'Techno Gamerz', 'Geet MP3', 'J Balvin',
#        'Jess No Limit', 'Jingle Toons', 'VEGETTA777',
#        'Galinha Pintadinha', 'SSSniperWolf', 'Desi Music Factory',
#        'Selena Gomez', 'Rajshri', 'Ch3Thailand', 'KHANDESHI MOVIES',
#        'NoCopyrightSounds', 'CVS 3D Rhymes & Kids Songs',
#        'Ricis Official', 'BabyBus - Kids Songs and Cartoons',
#        'Eros Now Music', 'BETER B��', 'DisneyMusicVEVO', 'The Weeknd',
#        'WowKidz', 'KAROL G', 'Mr Bean', 'rezendeevil', 'StarPlus',
#        'SMTOWN', 'GMA  Network', 'GENIAL', 'MR. INDIAN HACKER',
#        'Worldwide Records Bhojpuri', 'DONA ��', 'Dream',
#        'Lucas and Marcus', 'JustinBieberVEVO', 'Luis Fonsi',
#        'Peppa Pig - Official Channel', 'YOLO AVENTURAS',
#        'The Tonight Show Starring Jimmy Fallon', 'TheDonato',
#        'ImagineDragons', 'Diana and Roma ESP', 'Round2hell', 'Zee News',
#        'AboFlah', 'AH', 'Trap Nation', 'Adele', 'Talking Tom',
#        'Frost Diamond', "Spinnin' Records",
#        'Little Angel: Nursery Rhymes & Kids Songs', 'jacksepticeye',
#        'Shawn Mendes', 'ashish chanchlani vines', 'Ultra Records',
#        'Popular on YouTube', 'Maluma', 'Zhong', 'Enaldinho', 'AuronPlay',
#        'Shorts Break', 'infobells - Tamil', 'Aditya Music India',
#        'The Late Late Show with James Corden', 'Aditya Movies',
#        'Masha y el Oso', 'infobells - Telugu', 'HUM TV',
#        'Shemaroo Movies', 'Michael Jackson', 'Drake', 'Goldmines Dishoom',
#        'Sandeep Maheshwari', 'Bounce Patrol - Kids Songs', 'toycantando',
#        'MrBeast 2', 'Wiz Khalifa', 'JYP Entertainment', 'DanTDM',
#        'Nick Jr.', 'Crazy XYZ', 'ToyPuddingTV', 'Dushyant kukreja',
#        'Gulshan Kalra', 'Brent Rivera', 'Renato Garcia YT',
#        'Beast Reacts', 'enchufetv', 'Netflix', 'Raffy Tulfo in Action',
#        'WORLDSTARHIPHOP', 'Goldmines Bollywood', 'Alan Chikin Chow',
#        'PANDA BOI', 'BB Ki Vines', 'D Billions', 'Junya.����', 'Smosh',
#        '1MILLION Dance Studio', 'NichLmao', 'Mar�����', 'Indosiar',
#        'VanossGaming', 'David Guetta', 'LosPolinesios', 'Nicki Minaj',
#        'Fede Vigevani', 'TaylorSwiftVEVO', 'ZHC', 'Post Malone',
#        'Rans Entertainment', 'LankyBox', 'Coldplay', 'Las Ratitas',
#        'WB Kids', 'ABPLIVE', 'Chris Brown', 'The Lallantop',
#        'RihannaVEVO', 'WatchMojo.com', 'TRANS7 OFFICIAL', 'Anuel AA',
#        'Dan Rhodes', 'Yuya', "America's Got Talent", 'mujjuu___14',
#        'EminemVEVO', 'Chloe Ting', 'KatyPerryVEVO', 'Mark Rober',
#        'Like Nastya AE', 'Amit Bhadana', 'Pen Movies', 'shfa show India',
#        'Super JoJo - Nursery Rhymes & Kids Songs', 'Alejo Igoa',
#        'Daniel LaBelle', 'DJ Snake', 'Diana and Roma ARA', 'KSI',
#        'Spider Slack', 'Goldmines Movies', 'Preston', 'James Charles',
#        'Collins Key', 'Diana and Roma EN', 'Venus Entertainment',
#        'Troom Troom', 'Enrique Iglesias', 'Ninja', 'FaZe Rug',
#        'Mister Max', 'That Little Puff', 'NickyJamTV',
#        'Juan De Dios Pantoja', 'Logan Paul', 'Maya and Mary',
#        'Peppa Pig Espa���������', 'Jelly', 'Miss Katy', 'Tilak',
#        'Valentina Pontes ofc', 'Sesame Street', 'Happy Lives',
#        'Lady Gaga', 'Akshay Nagwadiya', 'Wave Music Bhojpuri',
#        'GMM GRAMMY OFFICIAL', 'TED', 'unknown boy varun',
#        'Kids TV - Nursery Rhymes And Baby Songs', 'Tsuriki Show',
#        'Technical Guruji', 'DrossRotzank', 'White Hill Music',
#        'Ultra Movie Parlour', 'Alan Becker', 'toyorbabytv',
#        'KL BRO Biju Rithvik', 'Vania Mania Kids', 'Like Nastya PRT',
#        'Sun TV', 'Heroindori', 'The Chainsmokers', 'mmoshaya', 'Sia',
#        'LeoNata Family', 'Goldmines Cineplex', 'Vlad and Niki Arabic',
#        'SSundee', 'Paulo Londra', 'Smile Family', 'FGTeeV',
#        'Kinder Spielzeug Kanal (Kidibli)', 'Charlie Puth',
#        'Vlad and Niki ESP', 'Sagawa /���', 'Ben Azelart',
#        'Zach Choi ASMR', 'Topper Guild', 'Disney Latinoam��',
#        'Stokes Twins', 'National Geographic', 'Dua Lipa',
#        'OneDirectionVEVO', 'Rotana', 'Netflix India',
#        'Sourav Joshi Vlogs', 'ZAMZAM ELECTRONICS TRADING', 'DUDU e CAROL',
#        'Village Cooking Channel', 'Eva Bravo Play', 'Tekashi 6ix9ine',
#        'Tlnovelas', 'SMOL', 'invictor', 'YOLO', 'Sidhu Moose Wala',
#        'The Royalty Family', 'Becky G', 'Ishaan Ali 11', 'Infinite',
#        'Azhan5star', 'Dangal TV Channel', 'Khan GS Research Centre',
#        'GMA Public  Affairs', 'Tasty', 'Baim Paula', 'nigahiga',
#        'Rafa & Luiz', 'Lyrical Lemonade', 'Vlad and Niki IDN',
#        'Dr. Vivek Bindra: Motivational Speaker', 'Fatos Desconhecidos',
#        'Brave Wilderness', 'LIV Crime', 'Minecraft - Topic',
#        'Romeo Santos', 'Canal Canalha', 'Yoeslan', '5-Minute Crafts DIY',
#        'Zach King', 'tuzelity SHUFFLE', 'NBA', 'Deddy Corbuzier',
#        'Bizarrap', 'Avicii', 'Mnet K-POP', 'LazarBeam', 'Ninja Kidz TV',
#        'Totoy kids - Portugu�', 'Jake Paul', 'Linkin Park',
#        'Vijay Television', 'SlivkiShow', 'Emiway Bantai',
#        'Got Talent Global', 'BabyBus - Cerita & Lagu Anak-anak',
#        'Ami Rodriguez', 'Noor Stars', 'Family GamesTV',
#        'Kiddiestv Hindi - Nursery Rhymes & Kids Songs', 'dednahype',
#        'Marta and Rustam', 'MiawAug', 'CookieSwirlC', 'Skrillex',
#        'AuthenticGames', 'Robin Hood Gamer', 'Pencilmation', '7clouds',
#        '5-Minute Crafts PLAY', 'Marvel Entertainment', 'BuzzFeedVideo',
#        'REACT', 'Vevo', 'Gordon Ramsay', 'Pentatonix',
#        'Green Gold TV - Official Channel', 'Gusttavo Lima Oficial',
#        'HaerteTest', 'Crafty Panda', 'SOMOY TV', 'JennaMarbles',
#        'Troom Troom Es', 'Official Pink Panther', "Britain's Got Talent",
#        'SCTV', 'AS Gaming', 'Sony AATH', 'tabii Urdu', 'DaFuq!?Boom!',
#        'Clash of Clans', 'RKD Studios', 'DLS News', 'JukiLop',
#        'etvteluguindia', 'FIFA', 'Manoj  parihar', 'Vsauce',
#        'Unbox Therapy', 'shane', 'Sonotek', 'Jimmy Kimmel Live',
#        'TheOdd1sOut', 'Goldmines Great Indian Comedy', 'Lil Nas X',
#        'SUPER SLICK SLIME SAM', 'Wow Kidz Action', 'Turma da M��',
#        'Calvin Harris', 'KBS WORLD TV', 'HiMan', 'Masha e o Urso',
#        'Little Angel Espa���������', 'TED-Ed', 'Sidemen', 'Cardi B',
#        'Busy Fun Ltd', 'Farruko', 'Triggered Insaan', 'CKN', 'Ali-A',
#        'Shemaroo Comedy', 'Smile Family Spanish', 'GRAMMY GOLD OFFICIAL',
#        'Dan-Sa / Daniel Saboya', 'Marmok', 'The ACE Family',
#        'Like Nastya Vlog', 'Willie Salim', 'PDK Films', 'TheWillyrex',
#        'RsiamMusic : ��������', 'Dhar Mann', 'shakiraVEVO',
#        'Naisa Alifia Yuriza (N.A.Y)', 'Miley Cyrus', 'IShowSpeed',
#        'Good Mythical Morning', 'Bobby chourasiya', 'Jake Fellman',
#        'GEN HALILINTAR', 'SQUEEZIE',
#        'Blippi - Educational Videos for Kids', 'officialpsy',
#        'Ajay Sharma', 'Manual do Mundo', 'How Ridiculous', 'And TV',
#        'Sebasti���', 'SonyMusicSouthVEVO', 'TheGrefg', 'BeatboxJCOP',
#        'David Dobrik', 'KatieAngel', 'RobleisIUTU', 'Lele Pons',
#        'Demi Lovato', 'Like Nastya VNM', 'Jason Derulo', 'MGC Playhouse',
#        'Zuni and Family', 'Priyal Kukreja',
#        'MSA previously My Story Animated', 'Jane ASMR ��',
#        'ArianaGrandeVevo', 'jaanvi patel', 'tanboy kun', 'Lil Pump',
#        'Porta dos Fundos', 'News 24', "Les' Copaque Production",
#        'El Payaso Plim Plim', 'zbing z.', 'MissaSinfonia',
#        'The Game Theorists', 'DeGoBooM', 'JFlaMusic', 'FactTechz',
#        'News18 India', 'Fun For Kids TV - Hindi Rhymes', 'IGN', 'Aphmau',
#        'AMARINTV : ������������', 'Koray Zeynep', 'Apple',
#        'Stubborn Facts', 'Taarak Mehta Ka Ooltah Chashmah', 'HowToBasic',
#        'PopularMMOs', 'Marques Brownlee', 'Anitta', 'Jason Vlogs',
#        'El Reino a Jugar', 'Willyrex', 'TheBrianMaps',
#        'TRANS TV Official', 'Liza Koshy', 'Queen Official',
#        'Prajapati News', 'Gaby and Alex', 'LuisFonsiVEVO',
#        'Pop Chartbusters', 'Guava Juice', 'EeOneGuy', 'VICE',
#        'Aayu and Pihu Show', 'Danny Fitt', 'Bispo Bruno Leonardo',
#        'DeToxoMoroxo', 'Doggy Doggy Cartoons', 'deepesh zo',
#        'Like Nastya IDN', 'Salman Noman', 'CoryxKenshin', 'Travis Scott',
#        'Tu COSMOPOLIS', 'Ivana Alawi', 'Werever2morro',
#        'IDEAS EN 5 MINUTOS', 'NMF News', 'SriBalajiMovies',
#        'Lahari Music - TSeries', 'Younes Zarou', 'Jordan Matter',
#        'FailArmy', 'BBC News Hindi', 'FunFun Toy Doll TV',
#        'Sandra Cires Art', 'Kaykai Salaider',
#        'UFC - Ultimate Fighting Championship', 'Ch7HD',
#        'RCTI - LAYAR DRAMA INDONESIA', 'Alfredo Larin',
#        'GMMTV OFFICIAL��', 'Matt Stonie', 'Boyce Avenue',
#        'Camila Cabello', 'Little Mix', 'SAM SMITH', 'Pitbull',
#        'Bollywood Classics', 'Technoblade', 'W2S', 'Jennifer Lopez',
#        'Kids Play', 'T3ddy', 'JJ Olatunji', 'POPS Kids',
#        'Thairath Online', 'LEGO', 'XO TEAM', 'AdMe', 'ExtraPolinesios',
#        'Dyland PROS', 'Live', 'Vlad and Niki ARA', 'Canal IN', 'TWICE',
#        'Daily Dose Of Internet', 'FitDance', 'Panda Shorts',
#        'Disney Junior', 'La Rosa de Guadalupe', 'sagar kalra (Shorts)',
#        'wifistudy', 'Antrax', 'Enes Batur', 'DopeLyrics', 'jeffreestar',
#        'Lyna', 'MK MUSIC', 'Unspeakable', 'Camilo', 'Dear Sir',
#        'Narendra Modi', 'Arif muhammad', 'Rotten Tomatoes Trailers',
#        'Volga Video', 'DM - Desi Melodies', 'MY FAMILY',
#        'Team Films Bhojpuri', 'Zee Music Classic', 'Prime Video India',
#        'Caeli YT', 'Linus Tech Tips', 'Juliana Baltar',
#        '5-Minute Crafts FAMILY', 'Super Senya', 'Katakit Baby TV',
#        'Infobells Bangla', 'Henrique e Juliano', 'Mr DegrEE',
#        'Kashvi Adlakha', 'Talking Tom & Friends', 'Harsh Beniwal',
#        'FFUNTV', 'Mobile Legends: Bang Bang', 'Roman Atwood Vlogs',
#        'Mrwhosetheboss', 'Genierock', 'zayn', 'Kerajinan 5-Menit',
#        'FC Barcelona', 'Dave and Ava - Nursery Rhymes and Baby Songs',
#        'LOKESH GAMER', 'ILYA BORZOV', 'Mazhavil Manorama', 'Pok���������',
#        'The MriDul', 'Niana Guerrero', 'SRK MUSIC', 'Sony LIV',
#        'T-Series Hamaar Bhojpuri', 'CNN', 'NDTV India', "It's Mamix",
#        'Kim Loaiza', 'Daftar Populer', 'Musas', 'Ranz Kyle',
#        'PowerfulJRE', 'Mariale', 'Makiman131', 'Hongyu ASMR ��',
#        'EdisonPts', 'BIGBANG', 'Rub������', 'ABS-CBN News', 'Chapitosiki',
#        'AdeleVEVO', 'MoreAliA', 'Chetan Monga Vlogs',
#        'Little Angel - M����������', 'League of Legends', 'TheRichest',
#        'XpressTV', 'PlayStation', 'Kwebbelkop', 'Republic Bharat',
#        'THE BROWN SIBLINGS', 'Sony Music South', 'BigSchool',
#        'Ray William Johnson', 'KOMPASTV', 'ISSEI / ����',
#        'A2 Motivation by Arvind Arora', '50 Cent', 'MNCTV OFFICIAL',
#        'ERB', 'melanie martinez', 'ZutiGang', 'TazerCraft', 'Bayashi TV',
#        'Fueled By Ramen', 'CrashCourse', 'MattyBRaps', 'Lachlan',
#        'Meghan Trainor', 'Jorge & Mateus Oficial', 'Major Lazer Official',
#        'Beast Philanthropy', 'Filaretiki', '5-Minute Crafts Recycle',
#        'Maha Fun Tv', 'Canal Nostalgia', 'The Slow Mo Guys',
#        'StudyIQ IAS', 'Chad Wild Clay', 'CollegeHumor', 'Netflix Jr.',
#        'Colors Rishtey', 'ABC News', 'Camila Loures', 'Doc Tops', 'Auron',
#        'Jesser', 'Planeta das G��', 'PrestonPlayz', 'Martin Garrix',
#        'O Reino Infantil', 'Fifth Harmony', 'Mis Pastelitos',
#        'Noman Official', 'LEGENDA FUNK', 'Like Nastya Stories',
#        'les boys tv2', 'Lotus Music', 'IDEIAS INCR��', 'Reaction Time',
#        'BBC News', 'Eli Kids - Cartoons & Songs', 'Aadishakti Films',
#        'Telemundo', 'GMM25Thailand', 'TV9 Bharatvarsh', 'Maroon5VEVO',
#        'Hear This Music', 'Lilly Singh', 'Gyan Gaming�', 'Drawblogs',
#        'NOBRU', 'Cyprien', 'Rclbeauty101', 'Coke Studio',
#        'Indore Physical Academy', 'Rosanna Pansino', 'Harry Styles',
#        'Vlad and Niki PRT', 'RS 1313 SHORTS', 'Zig & Sharko',
#        'SelenaGomezVEVO', 'ZEE5', 'Super Polina', 'Rebecca Zamolo',
#        'Wish 107.5', 'Invento na Hora', 'SIS vs BRO', 'NikkieTutorials',
#        'TommyInnit', 'E-MasterSensei', 'infobells - Kannada',
#        'Crazy Frog', 'The Dodo', 'SEVENGERS', 'Zee Bangla',
#        'DangMattSmith', 'Neha Kakkar', '#Refugio Mental', 'Trap City',
#        'Supercar Blondie', 'Yudist Ardhana', 'Lana Del Rey', 'MalumaVEVO',
#        'F2Freestylers - Ultimate Soccer Skills Channel', 'Bie The Ska',
#        'AM3NlC', 'Narins Beauty', 'TV Ana Emilia', 'Luli Pamp�',
#        'Gallina Pintadita', 'ViralHog', 'ETV Jabardasth', 'Zee Telugu',
#        'Crescendo com Luluca', 'Jazzghost', 'karameeshchannel',
#        'Darkar Company Studios', 'Dental Digest', 'T-Series Regional',
#        'ADEL et SAMI', 'Jamuna TV', 'Atlantic Records', 'Veritasium',
#        'Alexa Rivera', 'Airrack', 'Hacksmith Industries', 'JD Pantoja',
#        '123 GO! Spanish', 'Geo News',
#        'Kids TV India Hindi Nursery Rhymes', 'Think Music India',
#        'Goldmines Premiere', 'MAIKI021', 'The Vishal bhatt',
#        'NishaMadhulika', 'MyMissAnand', 'FAPTV', 'Wesley Safad�',
#        'infobells', 'Desi Gamers', 'Acenix', 'Zeinab Harake', 'DALLMYD',
#        'Lindsey Stirling', 'JOJO TV - Hindi Stories', 'BBC',
#        'Saturday Night Live', 'BUDI01 GAMING', 'Typical Gamer', 'Anaysa',
#        'JULIA GISELLA', 'Awakening Music', 'Lady Diana',
#        'Sanjoy Das Official', 'Woody & Kleiny', 'Vijay Kumar Viner Vlogs',
#        'Conor Maynard', 'Wengie', 'Vlad y Niki Show', 'Codiscos',
#        'The World Adventures ������', 'Vibhu 96', 'Blockbuster Movies',
#        'ATHLEAN-X�', 'My Mate Nate', 'H2ODelirious',
#        'GMA Integrated News', 'Peet Montzingo', 'The Q', 'Trakin Tech',
#        'theRadBrad', 'Matt Steffanina', 'Stray Kids',
#        'Kurt Hugo Schneider', 'Vogue', 'Kids Line�������', 'VexTrex',
#        'penguinz0', 'Just For Laughs Gags', "Kabita's Kitchen",
#        'BanderitaX', 'AzzyLand', 'HUBA��', 'Brawl Stars', 'Ei Nerd',
#        'Sonotek Bhakti', 'Vilmei', 'MC Divertida',
#        'The Infographics Show', 'jbalvinVEVO', 'Technology Gyan',
#        'CookingShooking Hindi', 'Ryan Trahan', 'Alex Gonzaga Official',
#        'WiederDude', 'Ian Boggs', 'Lokdhun Punjabi',
#        'Knowledge Tv ������', 'Painzeiro', 'Hungria Hip Hop',
#        'RaptorGamer', 'RedeTV', 'twenty one pilots', 'DJ Khaled',
#        'Davie504', 'Everson Zoio', 'Calon Sarjana', 'Lofi Girl',
#        'Jomy Production', "GH'S", 'JesseAndMike', 'Wolfoo Channel',
#        'Susy Mouriz', '7 Minutoz', 'The LaBrant Fam', 'Matheus Yurley',
#        'gymvirtual', 'Top Viral Talent', 'Akon', 'Rauw Alejandro',
#        'EnriqueIglesiasVEVO', 'The Shiny Peanut', 'Talking Angela',
#        'Duo Tiempo De Sol', 'Troom Troom India', 'MrSuicideSheep',
#        'Adam W', 'Right to Shiksha', 'Beyonc��', 'FACT FIRE KING',
#        'Ian Lucas', 'Franco Escamilla', 'Adexe & Nau',
#        'Diana and Roma IND', 'Jass Records', 'Future',
#        'YoungBoy Never Broke Again', 'Blossom', '#Ref����', 'Piuzinho',
#        'Heidi y Zidane', 'Go Ami Go!', 'Morgz', 'CaseyNeistat',
#        'NickiMinajAtVEVO', 'Ellie Goulding', 'colinfurze',
#        'People Vs Food', 'Wolfoo Family', 'Ja Mill', 'Health Time',
#        'Yair17', 'First We Feast', 'M����',
#        'Bebefinn - Nursery Rhymes & Kids Songs', 'Troom Troom PT',
#        'Parafernalha', 'NDTV', 'elcarteldesantatv', 'Family Fitness',
#        'Zee Tamil', 'Flowers Comedy', 'Mundo Bita', 'Wave Music Bhakti',
#        'Troom Troom Indonesia', 'CKM', 'Quantum Tech HD', '_vector_',
#        'DEV Ke Facts', 'Hero Movies 2023', 'LOUD', 'Gibby :)',
#        'Gustavo Par��', 'SAAIHALILINTAR', 'Timba Vk',
#        'Heidi and Zidane HZHtube', 'Zee Kids', "Pari's Lifestyle",
#        'DisneyChannelUK', 'MoniLina', 'bharatzkitchen HINDI', 'TKOR',
#        'ANNA KOVA', 'Avril Lavigne', 'Caylus', 'Migos ATL',
#        'Free Fire India Official', 'Panda', 'RobTopGames', 'Make Joke Of'],
#       dtype=object)

# %%
data.nunique()
# Out:
# rank                                       995
# Youtuber                                   934
# subscribers                                289
# video views                                988
# category                                    18
# Title                                      927
# uploads                                    777
# Country                                     49
# Abbreviation                                49
# channel_type                                14
# video_views_rank                           953
# country_rank                               246
# channel_type_rank                          286
# video_views_for_the_last_30_days           908
# lowest_monthly_earnings                    557
# highest_monthly_earnings                   736
# lowest_yearly_earnings                     757
# highest_yearly_earnings                    419
# subscribers_for_last_30_days                53
# created_year                                19
# created_month                               12
# created_date                                31
# Gross tertiary education enrollment (%)     47
# Population                                  48
# Unemployment rate                           47
# Urban_population                            48
# Latitude                                    48
# Longitude                                   48
# dtype: int64

# %%
data.describe()
# Out:
#         rank  subscribers     video views   uploads  video_views_rank  \
# count 995.00       995.00          995.00    995.00            994.00
# mean  498.00  22982412.06  11039537052.04   9187.13         554248.90
# std   287.38  17526105.34  14110844376.83  34151.35        1362782.21
# min     1.00  12300000.00            0.00      0.00              1.00
# 25%   249.50  14500000.00   4288145410.00    194.50            323.00
# 50%   498.00  17700000.00   7760819588.00    729.00            915.50
# 75%   746.50  24600000.00  13554701853.00   2667.50           3584.50
# max   995.00 245000000.00 228000000000.00 301308.00        4057944.00
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count        879.00             962.00                            939.00
# mean         386.05             745.72                      175610284.79
# std         1232.24            1944.39                      416378166.21
# min            1.00               1.00                              1.00
# 25%           11.00              27.00                       20137500.00
# 50%           51.00              65.50                       64085000.00
# 75%          123.00             139.75                      168826500.00
# max         7741.00            7741.00                     6589000000.00
#
#        lowest_monthly_earnings  highest_monthly_earnings  ...  \
# count                   995.00                    995.00  ...
# mean                  36886.15                 589807.85  ...
# std                   71858.72                1148622.48  ...
# min                       0.00                      0.00  ...
# 25%                    2700.00                  43500.00  ...
# 50%                   13300.00                 212700.00  ...
# 75%                   37900.00                 606800.00  ...
# max                  850900.00               13600000.00  ...
#
#        highest_yearly_earnings  subscribers_for_last_30_days  created_year  \
# count                   995.00                        658.00        990.00
# mean                7081813.92                     349079.13       2012.63
# std                13797037.61                     614355.44          4.51
# min                       0.00                          1.00       1970.00
# 25%                  521750.00                     100000.00       2009.00
# 50%                 2600000.00                     200000.00       2013.00
# 75%                 7300000.00                     400000.00       2016.00
# max               163400000.00                    8000000.00       2022.00
#
#        created_date  Gross tertiary education enrollment (%)    Population  \
# count        990.00                                   872.00        872.00
# mean          15.75                                    63.63  430387266.75
# std            8.78                                    26.11  472794722.46
# min            1.00                                     7.60     202506.00
# 25%            8.00                                    36.30   83355411.00
# 50%           16.00                                    68.00  328239523.00
# 75%           23.00                                    88.20  328239523.00
# max           31.00                                   113.10 1397715000.00
#
#        Unemployment rate  Urban_population  Latitude  Longitude
# count             872.00            872.00    872.00     872.00
# mean                9.28      224214981.63     26.63     -14.13
# std                 4.89      154687362.71     20.56      84.76
# min                 0.75          35588.00    -38.42    -172.10
# 25%                 5.27       55908316.00     20.59     -95.71
# 50%                 9.37      270663028.00     37.09     -51.93
# 75%                14.70      270663028.00     37.09      78.96
# max                14.72      842933962.00     61.92     138.25
#
# [8 rows x 21 columns]

# %%
data["Youtuber"].value_counts()
# Out:
# Youtuber
# False                                           62
# T-Series                                         1
# NDTV India                                       1
# FC Barcelona                                     1
# Dave and Ava - Nursery Rhymes and Baby Songs     1
#                                                 ..
# OneDirectionVEVO                                 1
# Rotana                                           1
# Netflix India                                    1
# Sourav Joshi Vlogs                               1
# Make Joke Of                                     1
# Name: count, Length: 934, dtype: int64

# %%
data.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# created_month                                5
# created_date                                 5
# Gross tertiary education enrollment (%)    123
# Population                                 123
# Unemployment rate                          123
# Urban_population                           123
# Latitude                                   123
# Longitude                                  123
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.dropna(axis=0, inplace=True)

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.dtypes
# Out:
# rank                                         int64
# Youtuber                                    object
# subscribers                                  int64
# video views                                  int64
# category                                    object
# Title                                       object
# uploads                                      int64
# Country                                     object
# Abbreviation                                object
# channel_type                                object
# video_views_rank                           float64
# country_rank                               float64
# channel_type_rank                          float64
# video_views_for_the_last_30_days           float64
# lowest_monthly_earnings                    float64
# highest_monthly_earnings                   float64
# lowest_yearly_earnings                     float64
# highest_yearly_earnings                    float64
# subscribers_for_last_30_days               float64
# created_year                               float64
# created_month                               object
# created_date                               float64
# Gross tertiary education enrollment (%)    float64
# Population                                 float64
# Unemployment rate                          float64
# Urban_population                           float64
# Latitude                                   float64
# Longitude                                  float64
# dtype: object

# %%
data["Population"]=data["Population"].astype("int")

# %%
data.dtypes
# Out:
# rank                                         int64
# Youtuber                                    object
# subscribers                                  int64
# video views                                  int64
# category                                    object
# Title                                       object
# uploads                                      int64
# Country                                     object
# Abbreviation                                object
# channel_type                                object
# video_views_rank                           float64
# country_rank                               float64
# channel_type_rank                          float64
# video_views_for_the_last_30_days           float64
# lowest_monthly_earnings                    float64
# highest_monthly_earnings                   float64
# lowest_yearly_earnings                     float64
# highest_yearly_earnings                    float64
# subscribers_for_last_30_days               float64
# created_year                               float64
# created_month                               object
# created_date                               float64
# Gross tertiary education enrollment (%)    float64
# Population                                   int32
# Unemployment rate                          float64
# Urban_population                           float64
# Latitude                                   float64
# Longitude                                  float64
# dtype: object

# %%
data.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
data.sort_values(by='video_views_rank',ascending = True).head(5)
# Out:
#     rank                    Youtuber  subscribers   video views   category  \
# 0      1                    T-Series    245000000  228000000000      Music
# 3      4  Cocomelon - Nursery Rhymes    162000000  164000000000  Education
# 4      5                   SET India    159000000  148000000000      Shows
# 15    16                    Sony SAB     83000000  101000000000      Shows
# 11    12                         WWE     96000000   77428473662     Sports
#
#                          Title  uploads        Country Abbreviation  \
# 0                     T-Series    20082          India           IN
# 3   Cocomelon - Nursery Rhymes      966  United States           US
# 4                    SET India   116536          India           IN
# 15                    Sony SAB    71270          India           IN
# 11                         WWE    70127  United States           US
#
#      channel_type  ...  subscribers_for_last_30_days  created_year  \
# 0           Music  ...                    2000000.00       2006.00
# 3       Education  ...                    1000000.00       2006.00
# 4   Entertainment  ...                    1000000.00       2006.00
# 15  Entertainment  ...                    1100000.00       2007.00
# 11         Sports  ...                     600000.00       2007.00
#
#     created_month  created_date  Gross tertiary education enrollment (%)  \
# 0             Mar         13.00                                    28.10
# 3             Sep          1.00                                    88.20
# 4             Sep         20.00                                    28.10
# 15            Aug          4.00                                    28.10
# 11            May         11.00                                    88.20
#
#     Population  Unemployment rate  Urban_population  Latitude  Longitude
# 0   1366417754               5.36      471031528.00     20.59      78.96
# 3    328239523              14.70      270663028.00     37.09     -95.71
# 4   1366417754               5.36      471031528.00     20.59      78.96
# 15  1366417754               5.36      471031528.00     20.59      78.96
# 11   328239523              14.70      270663028.00     37.09     -95.71
#
# [5 rows x 28 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
top_3_youtubers = data.groupby('Youtuber')['rank'].mean().sort_values().head(3).index
data_top_3 = data[data['Youtuber'].isin(top_3_youtubers)]

sns.barplot(x="Youtuber", y="subscribers", data=data_top_3)
# Out:
# <Axes: xlabel='Youtuber', ylabel='subscribers'>
